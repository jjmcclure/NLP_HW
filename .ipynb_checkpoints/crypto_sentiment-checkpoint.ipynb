# %% [markdown]
# # News Headlines Sentiment
#
# Use the news api to pull the latest news articles for bitcoin and ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline

# %%
# Read your api key environment variable
# YOUR CODE HERE!
path="C:\\Users\\James McClure\\.env"
load_dotenv(dotenv_path=path)
api_key = os.getenv("news_api")
print(api_key)
# Out:
# 497d123b68434da584c878cbabdb14c9

# %%
# Create a newsapi client
# YOUR CODE HERE!
from newsapi import NewsApiClient
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
# YOUR CODE HERE!
btc_news_en = newsapi.get_everything(
    q="Bitcoin AND BTC",
    language="en"
)

# Show the total number of news
btc_news_en["totalResults"]
# Out:
# 1321

# %%
# Fetch the Ethereum news articles
# YOUR CODE HERE!
eth_news_en = newsapi.get_everything(
    q="Ethereum AND ETH",
    language="en"
)

# Show the total number of news
eth_news_en["totalResults"]
# Out:
# 465

# %%
# Create the Bitcoin sentiment scores DataFrame
# YOUR CODE HERE!
btc_sentiments = []

for article in btc_news_en["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        btc_sentiments.append({
            "Compound": compound,
            "Negative": neg,
            "Neutral": neu,
            "Positive": pos,
            "text": text,
            "token":""
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
btc_df = pd.DataFrame(btc_sentiments)

# # Reorder DataFrame columns
# cols = ["Compound", "Negative", "Neutral", "Positive", "text", "token"]
# btc_df = btc_df[cols]

btc_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.5106     0.000    0.878     0.122
# 1   -0.2677     0.074    0.881     0.045
# 2    0.5070     0.000    0.910     0.090
# 3    0.7096     0.000    0.831     0.169
# 4    0.5070     0.000    0.910     0.090
#
#                                                 text token
# 0  A ransomware variant called NetWalker is doing...
# 1  An outspoken Bitcoin whale who rarely shows af...
# 2  Our robot colleague Satoshi Nakaboto writes ab...
# 3  Seminal crypto-fund Grayscale Bitcoin BTC Trus...
# 4  Our robot colleague Satoshi Nakaboto writes ab...

# %%
# Create the ethereum sentiment scores DataFrame
# YOUR CODE HERE!
eth_sentiments = []

for article in eth_news_en["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        eth_sentiments.append({
            "Compound": compound,
            "Negative": neg,
            "Neutral": neu,
            "Positive": pos,
            "text": text,
            "token":""
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
eth_df = pd.DataFrame(eth_sentiments)

# # Reorder DataFrame columns
# cols = ["Compound", "Negative", "Neutral", "Positive", "text"]
# eth_df = eth_df[cols]

eth_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.2484     0.000    0.943     0.057
# 1   -0.2732     0.052    0.948     0.000
# 2    0.0000     0.000    1.000     0.000
# 3    0.4404     0.000    0.906     0.094
# 4    0.6486     0.000    0.858     0.142
#
#                                                 text token
# 0  Ethereum is one of the most growing cryptocurr...
# 1  On Aug. 2, the price of Ethereum peaked at $41...
# 2  Ethereum 2.0s final and official public testne...
# 3  Though now evolved in many ways, Gavin Wood wr...
# 4  Hopes the bottleneck on the Ethereum blockchai...

# %%
# Describe the Bitcoin Sentiment
# YOUR CODE HERE!
btc_df.describe()
# Out:
#         Compound   Negative    Neutral   Positive
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.487265   0.003700   0.899850   0.096450
# std     0.186891   0.016547   0.022958   0.025574
# min    -0.267700   0.000000   0.831000   0.045000
# 25%     0.507000   0.000000   0.910000   0.090000
# 50%     0.507000   0.000000   0.910000   0.090000
# 75%     0.507000   0.000000   0.910000   0.090000
# max     0.709600   0.074000   0.910000   0.169000

# %%
# Describe the Ethereum Sentiment
# YOUR CODE HERE!
eth_df.describe()
# Out:
#         Compound   Negative    Neutral   Positive
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.161245   0.020350   0.928000   0.051600
# std     0.340849   0.045902   0.076318   0.056516
# min    -0.599400   0.000000   0.749000   0.000000
# 25%     0.000000   0.000000   0.899750   0.000000
# 50%     0.088950   0.000000   0.942000   0.052500
# 75%     0.440400   0.008750   1.000000   0.080000
# max     0.771700   0.189000   1.000000   0.165000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Bitcoin
#
# Q: Which coin had the highest compound score?
#
# A: Bitcoin
#
# Q. Which coin had the highest positive score?
#
# A: Bitcoin

# %% [markdown]
# ---

# %% [markdown]
# # Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word
# 2. Remove Punctuation
# 3. Remove Stopwords

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\James
# [nltk_data]     McClure\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\James
# [nltk_data]     McClure\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Expand the default stopwords list if necessary
# YOUR CODE HERE!
sw_addon = {'fucking'}

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    #remove punctuation
    no_punks = re.compile("[^a-zA-Z ]")
    clean = no_punks.sub('', text)
    # Create a list of the words
    words = word_tokenize(clean)
    # Remove the stop words
    sw = set(stopwords.words('english'))
    # Lemmatize Words into root words
    lem = [lemmatizer.lemmatize(word) for word in words]
    tokens = [word.lower() for word in lem if word.lower() not in sw.union(sw_addon)]
    return tokens

# %%
# Create a new tokens column for bitcoin
# YOUR CODE HERE!
all_btc_words = []
for i in btc_df.index:
    token = tokenizer(btc_df['text'][i])
    btc_df['token'][i] = token
    for bit in token:
        all_btc_words.append(bit)
btc_df.head()
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    Compound  Negative  Neutral  Positive  \
# 0    0.5106     0.000    0.878     0.122
# 1   -0.2677     0.074    0.881     0.045
# 2    0.5070     0.000    0.910     0.090
# 3    0.7096     0.000    0.831     0.169
# 4    0.5070     0.000    0.910     0.090
#
#                                                 text  \
# 0  A ransomware variant called NetWalker is doing...
# 1  An outspoken Bitcoin whale who rarely shows af...
# 2  Our robot colleague Satoshi Nakaboto writes ab...
# 3  Seminal crypto-fund Grayscale Bitcoin BTC Trus...
# 4  Our robot colleague Satoshi Nakaboto writes ab...
#
#                                                token
# 0  [ransomware, variant, called, netwalker, surpr...
# 1  [outspoken, bitcoin, whale, rarely, show, affe...
# 2  [robot, colleague, satoshi, nakaboto, writes, ...
# 3  [seminal, cryptofund, grayscale, bitcoin, btc,...
# 4  [robot, colleague, satoshi, nakaboto, writes, ...

# %%
# Create a new tokens column for ethereum
# YOUR CODE HERE!
all_eth_words = []
for i in eth_df.index:
    token = tokenizer(eth_df['text'][i])
    eth_df['token'][i] = token
    for bit in token:
        all_eth_words.append(bit)
eth_df.head()
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    Compound  Negative  Neutral  Positive  \
# 0    0.2484     0.000    0.943     0.057
# 1   -0.2732     0.052    0.948     0.000
# 2    0.0000     0.000    1.000     0.000
# 3    0.4404     0.000    0.906     0.094
# 4    0.6486     0.000    0.858     0.142
#
#                                                 text  \
# 0  Ethereum is one of the most growing cryptocurr...
# 1  On Aug. 2, the price of Ethereum peaked at $41...
# 2  Ethereum 2.0s final and official public testne...
# 3  Though now evolved in many ways, Gavin Wood wr...
# 4  Hopes the bottleneck on the Ethereum blockchai...
#
#                                                token
# 0  [ethereum, one, growing, cryptocurrencies, rec...
# 1  [aug, price, ethereum, peaked, within, minute,...
# 2  [ethereum, final, official, public, testnet, m...
# 3  [though, evolved, many, way, gavin, wood, wrot...
# 4  [hopes, bottleneck, ethereum, blockchain, migh...

# %% [markdown]
# ---

# %% [markdown]
# # NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
# YOUR CODE HERE!
#create a word list for all articles
btc_counts = Counter(ngrams(all_btc_words, n=2))
print(dict(btc_counts.most_common(10)))
# Out:
# {('satoshi', 'nakaboto'): 32, ('bitcoin', 'btc'): 17, ('char', 'robot'): 16, ('robot', 'colleague'): 16, ('colleague', 'satoshi'): 16, ('nakaboto', 'writes'): 16, ('writes', 'bitcoin'): 16, ('btc', 'every'): 16, ('every', 'daywelcome'): 16, ('daywelcome', 'another'): 16}

# %%
# Generate the Ethereum N-grams where N=2
# YOUR CODE HERE!
eth_counts = Counter(ngrams(all_eth_words, n=2))
print(dict(eth_counts.most_common(10)))
# Out:
# {('btc', 'trading'): 4, ('trading', 'around'): 4, ('char', 'ethereum'): 3, ('recent', 'time'): 2, ('launch', 'eth'): 2, ('decentralized', 'exchange'): 2, ('char', 'bitcoins'): 2, ('bitcoins', 'price'): 2, ('fee', 'ethereum'): 2, ('around', 'char'): 2}

# %%
# Use the token_count function to generate the top 10 words from each coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Get the top 10 words for Bitcoin
# YOUR CODE HERE!
top_btc = token_count(all_btc_words)

# %%
# Get the top 10 words for Ethereum
# YOUR CODE HERE!
top_eth = token_count(all_eth_words)

# %% [markdown]
# # Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
# YOUR CODE HERE!
cloud_btc = ' '.join(all_btc_words)
wc = WordCloud().generate(cloud_btc)
plt.imshow(wc)

# %%
# Generate the Ethereum word cloud
# YOUR CODE HERE!
cloud_eth = ' '.join(all_eth_words)
wc = WordCloud().generate(cloud_eth)
plt.imshow(wc)

# %% [markdown]
# # Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both coins and visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Optional - download a language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## Bitcoin NER

# %%
# Concatenate all of the bitcoin text together
# YOUR CODE HERE!
concat_btc = ""
for word in all_btc_words:
    concat_btc += word + " "

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!
doc = nlp(concat_btc)
# Add a title to the document
# YOUR CODE HERE!
doc.user_data["title"] = "Bitcoin NER"

# %%
# Render the visualization
# YOUR CODE HERE!
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">ransomware variant called
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     netwalker
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  surprisingly well even economy malware take computer hostage asks
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  ransom raked
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  last
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     five
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  char outspoken bitcoin whale rarely show affection anything btc say
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  crypto asset potentialthe pseudonymous trader known
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     joe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  say
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     unus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  sed
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     leo leo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  may solo char robot colleague satoshi nakaboto writes
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  btc every daywelcome another edition
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  satoshi nakaboto tell whats going bitcoin char seminal cryptofund
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     grayscale bitcoin btc trust gbtc exchange
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  traded product invests exclusively
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  pantsthreatening
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     billion year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  growth
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     six month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  char robot colleague
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     satoshi nakaboto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  writes
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  btc every daywelcome another edition
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  satoshi nakaboto tell whats going
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bitcoin char cryptocurrency exchange
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  bitfinex
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     offering million return billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  worth
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertic

# %%
# List all Entities
# YOUR CODE HERE!
print([ent.text for ent in doc.ents if ent.label_ == 'GPE'])
# Out:
# ['bitcoin', 'bitcoin', 'bitcoin', 'bitcoin', 'bitcoin', 'bitcoin', 'bitcoin', 'bitcoin', 'bitcoin', 'bitcoin', 'bitcoin', 'bitcoin', 'bitcoin', 'bitcoin', 'bitcoin', 'bitcoin', 'bitcoin', 'bitcoin', 'bitcoin', 'bitcoin', 'bitcoin', 'bitcoin', 'bitcoin', 'bitcoin', 'bitcoin', 'bitcoin', 'bitcoin', 'bitcoin', 'bitcoin', 'bitcoin', 'bitcoin', 'bitcoin', 'bitcoin', 'bitcoin', 'bitcoin', 'bitcoin']

# %% [markdown]
# ---

# %% [markdown]
# ## Ethereum NER

# %%
# Concatenate all of the bitcoin text together
# YOUR CODE HERE!
concat_eth = ""
for word in all_eth_words:
    concat_eth += word + " "

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!
doc = nlp(concat_eth)
# Add a title to the document
# YOUR CODE HERE!
doc.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
# YOUR CODE HERE!
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">ethereum one growing cryptocurrencies recent time youre looking forward investing world
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  peertopeer computing network youre
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  char aug price ethereum peaked within
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     minute
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  dropped binance futures eth plunged low recovering back within minutesthe e char ethereum final official public testnet medalla live according ethereum foundationullimedalla final testnet launch eth network char though evolved many way gavin wood wrote ethereums yellow paper key functionality blockchain turingcomplete language effectively unlimited intertransaction char hopes bottleneck ethereum blockchain might ease sent token associated decentralized exchange known dex token soaring token x exchange zrx rallying char bitcoins price
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mondays
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  high meanwhile high fee ethereum helped decentralized exchange uniswap rake million past
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     monthullibitcoin btc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  trading around char defi dad defi super user sharing money experiment tutorial twitter youtube organizing member ethereal summit sessions host ethereal podcast char send cryptodollars back forth without paying fee ethereum network according
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     centre consortium
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     blog post
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  ullidubbed
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     usdc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  usd coin usdc ha char ethereum transaction fee soaring
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     daily
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  profit achieved miner network highest point monthsullidata bitinfocharts show
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     daily
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  char
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     five year ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  week first generalpurpose blockchain went live mainnet ethereum paved way whole new use case blockchain technology untethered bitcoins original vision char everyone may talking governance ethereum yettolaunch stablecoin startup liquity taking contrarian view
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     zero
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  governancethat doesnt mean wont offer yield farming char price btc bouncing
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eth miner
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  rise coindesks markets daily back news roundup early access regular
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     noon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  eastern time release subscribe withap char bitcoin making lost gain hitting oneweek low ethereum fee situation continues problematic tradersullibitcoin btc trading around char human ingenuity find way around limitation sometimes limitation obstacle way progress creative thinking come new path sometimes limitation lack char ethereum ha delayed may still see launch eth staking fall time investor decide stake ethereum promise earnings char vernon az accesswire
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     august
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  recent
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     time ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  network ha encountered numerous flaw future eth hanging balance market mature crypt char bitcoins price trending ethereum competitor entering defi race weekendullibitcoin btc tradin

# %%
# List all Entities
# YOUR CODE HERE!
print([ent.text for ent in doc.ents if ent.label_ == 'GPE'])
# Out:
# []
